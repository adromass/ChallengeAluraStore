# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Markdown
import folium
from folium.plugins import HeatMap

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# 1. Calcular el ingreso total por tienda (suma de la columna 'Precio')
ingresoTotalTienda = tienda['Precio'].sum()
ingresoTotalTienda2 = tienda2['Precio'].sum()
ingresoTotalTienda3 = tienda3['Precio'].sum()
ingresoTotalTienda4 = tienda4['Precio'].sum()
#f"${tienda['Precio'].sum():,.2f}"

# 2 Función para contar productos por categoría
def ventas_por_categoria(df):
    conteo = df.groupby('Categoría del Producto')['Producto'].count().reset_index()
    conteo.columns = ['Categoría', 'Ventas']
    conteo = conteo.sort_values('Ventas', ascending=False).reset_index(drop=True)
    conteo.index = conteo.index + 1
    display(Markdown("### Ventas por categoría"))
    display(conteo)
    return

# 3 Función para calcular promedio de calificaciones por tienda
def promedio_calificaciones(df):
    promedio = df['Calificación'].mean()
    return f"{promedio:,.2f}"

# 4 Función para analizar productos más/menos vendidos
def analizar_ventas_productos(df):
    # Contar ventas por producto
    ventas_por_producto = df['Producto'].value_counts().reset_index()
    ventas_por_producto.columns = ['Producto', 'Ventas']
    
    # Ordenar de mayor a menor
    ventas_por_producto = ventas_por_producto.sort_values('Ventas', ascending=False)
    
    # Obtener top 5 más vendidos y top 5 menos vendidos
    top_mas_vendidos = ventas_por_producto.head(10)
    top_menos_vendidos = ventas_por_producto.tail(10).sort_values('Ventas', ascending=True).reset_index(drop=True)
    
    top_mas_vendidos.index = top_mas_vendidos.index + 1
    top_menos_vendidos.index = top_menos_vendidos.index + 1
    
    display(Markdown("### Productos Más Vendidos"))
    display(top_mas_vendidos)
    display(Markdown("### Productos Menos Vendidos"))
    display(top_menos_vendidos)
    
    return

# 5 Función para calcular costo de envío promedio
def costo_envio_promedio(df):
    promedio = df['Costo de envío'].mean()
    return promedio
    #f"${promedio:,.2f}"
    #print(f"Costo de envío promedio en {nombre_tienda}: ${promedio:.2f}")


#funcion para presentar datos como tabla
def crear_tabla (nombres, *datos):
    df=pd.DataFrame(datos, columns=nombres)
    #display(df)
    display(df.style.hide(axis="index").hide(axis="columns"))
    return

#funcion para crear un grafico circular

def graficar_circular(etiquetas, valores, titulo):
    plt.figure(figsize=(3, 3))
    plt.pie(valores, labels=etiquetas, autopct='%1.1f%%', startangle=90)
    plt.axis('equal')
    plt.title(titulo)
    plt.show()

#funcion para grafica de dispersion sobre las ventas

def mapa_calor_tiendas():
    # Crear copias de las coordenadas de cada tienda
    latlon_tienda1 = tienda[['lat', 'lon']].copy()
    latlon_tienda2 = tienda2[['lat', 'lon']].copy()
    latlon_tienda3 = tienda3[['lat', 'lon']].copy()
    latlon_tienda4 = tienda4[['lat', 'lon']].copy()

    # Agregar una columna de nombre
    latlon_tienda1['Tienda'] = 'tienda 1'
    latlon_tienda2['Tienda'] = 'tienda 2'
    latlon_tienda3['Tienda'] = 'tienda 3'
    latlon_tienda4['Tienda'] = 'tienda 4'

    # Unir todos los datos para calcular el centro
    datos = pd.concat(
        [latlon_tienda1, latlon_tienda2, latlon_tienda3, latlon_tienda4],
        ignore_index=True
    )

    # Crear el mapa centrado en el promedio de todas las ubicaciones
    mapa = folium.Map(location=[datos['lat'].mean(), datos['lon'].mean()], zoom_start=6)

    # Crear un grupo para cada tienda con su HeatMap
    for tienda_df, nombre, color in zip(
        [latlon_tienda1, latlon_tienda2, latlon_tienda3, latlon_tienda4],
        ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
        ['red', 'blue', 'green', 'purple']
    ):
        puntos = tienda_df[['lat', 'lon']].values.tolist()
        grupo = folium.FeatureGroup(name=nombre)
        HeatMap(puntos, radius=10, blur=15, gradient=None).add_to(grupo)
        grupo.add_to(mapa)

    # Agregar control de capas
    folium.LayerControl(collapsed=False).add_to(mapa)

    return mapa
#Analisis tienda 1

display(Markdown("# Análisis De Tienda 1"))

crear_tabla(
    ["nombre", "datos"],
    ["Ingresos Totales", ingresoTotalTienda],
    ["Costo de envio promedio", costo_envio_promedio(tienda)],
    ["Promedio de calificación", promedio_calificaciones(tienda)]
)

ventas_por_categoria(tienda)

analizar_ventas_productos(tienda)

#Analisis tienda 2

display(Markdown("# Análisis De Tienda 2"))

crear_tabla(
    ["nombre", "datos"],
    ["Ingresos Totales", ingresoTotalTienda2],
    ["Costo de envio promedio", costo_envio_promedio(tienda2)],
    ["Promedio de calificación", promedio_calificaciones(tienda2)]
)

ventas_por_categoria(tienda2)

analizar_ventas_productos(tienda2)

#Analisis tienda 3

display(Markdown("# Análisis De Tienda 3"))

crear_tabla(
    ["nombre", "datos"],
    ["Ingresos Totales", ingresoTotalTienda3],
    ["Costo de envio promedio", costo_envio_promedio(tienda3)],
    ["Promedio de calificación", promedio_calificaciones(tienda3)]
)

ventas_por_categoria(tienda3)

analizar_ventas_productos(tienda3)

#Analisis tienda 4

display(Markdown("# Análisis De Tienda 4"))

crear_tabla(
    ["nombre", "datos"],
    ["Ingresos Totales", ingresoTotalTienda4],
    ["Costo de envio promedio", costo_envio_promedio(tienda4)],
    ["Promedio de calificación", promedio_calificaciones(tienda4)]
)

ventas_por_categoria(tienda4)

analizar_ventas_productos(tienda4)

#Graficas para analizar las tiendas

display(Markdown("# Análisis De Tiendas"))

display(Markdown("## Análisis De Ingresos por Tienda"))

graficar_circular(
    ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda4'],
    [ingresoTotalTienda, ingresoTotalTienda2, ingresoTotalTienda3, ingresoTotalTienda4],
    'Ingresos Totales'
)

display(Markdown("## Análisis De Costos De Envio Promedio por Tienda"))

graficar_circular(
    ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda4'],
    [costo_envio_promedio(tienda), costo_envio_promedio(tienda2), costo_envio_promedio(tienda3), costo_envio_promedio(tienda4)],
    'Costos de Envio Promedio'
)

#grafica de dispersion

colores = {
    'tienda 1': 'red',
    'tienda 2': 'blue',
    'tienda 3': 'green',
    'tienda 4': 'purple'
}



# Crear el mapa centrado en el promedio de todas las ubicaciones


mapa_calor_tiendas()
# Out:
# # Análisis De Tienda 1
# <style type="text/css">
# </style>
# <table id="T_b1211">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b1211_row0_col0" class="data row0 col0" >Ingresos Totales</td>
#       <td id="T_b1211_row0_col1" class="data row0 col1" >1150880400.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b1211_row1_col0" class="data row1 col0" >Costo de envio promedio</td>
#       <td id="T_b1211_row1_col1" class="data row1 col1" >26018.609580</td>
#     </tr>
#     <tr>
#       <td id="T_b1211_row2_col0" class="data row2 col0" >Promedio de calificación</td>
#       <td id="T_b1211_row2_col1" class="data row2 col1" >3.98</td>
#     </tr>
#   </tbody>
# </table>
# ### Ventas por categoría
#                  Categoría  Ventas
# 1                  Muebles     465
# 2             Electrónicos     448
# 3                 Juguetes     324
# 4        Electrodomésticos     312
# 5     Deportes y diversión     284
# 6   Instrumentos musicales     182
# 7                   Libros     173
# 8  Artículos para el hogar     171
# ### Productos Más Vendidos
#                    Producto  Ventas
# 1                Microondas      60
# 2             TV LED UHD 4K      60
# 3                   Armario      60
# 4          Secadora de ropa      58
# 5             Mesa de noche      56
# 6   Bloques de construcción      56
# 7       Balón de baloncesto      55
# 8                 Bicicleta      54
# 9              Vaso térmico      54
# 10             Refrigerador      54
# ### Productos Menos Vendidos
#                        Producto  Ventas
# 1                  Celular ABXY      33
# 2     Auriculares con micrófono      33
# 3               Olla de presión      35
# 4                     Pandereta      36
# 5                       Mochila      39
# 6   Ciencia de datos con Python      39
# 7            Cuerda para saltar      40
# 8                Dinosaurio Rex      40
# 9                   Muñeca bebé      40
# 10              Mesa de comedor      40
# # Análisis De Tienda 2
# <style type="text/css">
# </style>
# <table id="T_58aa0">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_58aa0_row0_col0" class="data row0 col0" >Ingresos Totales</td>
#       <td id="T_58aa0_row0_col1" class="data row0 col1" >1116343500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_58aa0_row1_col0" class="data row1 col0" >Costo de envio promedio</td>
#       <td id="T_58aa0_row1_col1" class="data row1 col1" >25216.235693</td>
#     </tr>
#     <tr>
#       <td id="T_58aa0_row2_col0" class="data row2 col0" >Promedio de calificación</td>
#       <td id="T_58aa0_row2_col1" class="data row2 col1" >4.04</td>
#     </tr>
#   </tbody>
# </table>
# ### Ventas por categoría
#                  Categoría  Ventas
# 1                  Muebles     442
# 2             Electrónicos     422
# 3                 Juguetes     313
# 4        Electrodomésticos     305
# 5     Deportes y diversión     275
# 6   Instrumentos musicales     224
# 7                   Libros     197
# 8  Artículos para el hogar     181
# ### Productos Más Vendidos
#                      Producto  Ventas
# 1   Iniciando en programación      65
# 2                  Microondas      62
# 3                     Batería      61
# 4           Guitarra acústica      58
# 5                   Pandereta      58
# 6            Secadora de ropa      57
# 7                   Iphone 15      55
# 8     Bloques de construcción      54
# 9                     Armario      54
# 10               Set de ollas      52
# ### Productos Menos Vendidos
#              Producto  Ventas
# 1       Juego de mesa      32
# 2     Mesa de comedor      34
# 3           Impresora      34
# 4              Sillón      35
# 5         Auriculares      37
# 6   Asistente virtual      38
# 7          Cubertería      39
# 8            Smart TV      40
# 9        Celular ABXY      41
# 10     Dinosaurio Rex      42
# # Análisis De Tienda 3
# <style type="text/css">
# </style>
# <table id="T_7016c">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7016c_row0_col0" class="data row0 col0" >Ingresos Totales</td>
#       <td id="T_7016c_row0_col1" class="data row0 col1" >1098019600.000000</td>
#     </tr>
#     <tr>
#       <td id="T_7016c_row1_col0" class="data row1 col0" >Costo de envio promedio</td>
#       <td id="T_7016c_row1_col1" class="data row1 col1" >24805.680373</td>
#     </tr>
#     <tr>
#       <td id="T_7016c_row2_col0" class="data row2 col0" >Promedio de calificación</td>
#       <td id="T_7016c_row2_col1" class="data row2 col1" >4.05</td>
#     </tr>
#   </tbody>
# </table>
# ### Ventas por categoría
#                  Categoría  Ventas
# 1                  Muebles     499
# 2             Electrónicos     451
# 3                 Juguetes     315
# 4        Electrodomésticos     278
# 5     Deportes y diversión     277
# 6                   Libros     185
# 7  Artículos para el hogar     177
# 8   Instrumentos musicales     177
# ### Productos Más Vendidos
#                      Producto  Ventas
# 1               Kit de bancas      57
# 2             Mesa de comedor      56
# 3                   Cama king      56
# 4                Set de ollas      55
# 5               Mesa de noche      55
# 6                    Smart TV      54
# 7                      Estufa      53
# 8          Cuerda para saltar      53
# 9         Modelado predictivo      53
# 10  Carrito de control remoto      52
# ### Productos Menos Vendidos
#                      Producto  Ventas
# 1     Bloques de construcción      35
# 2                Set de vasos      36
# 3                  Microondas      36
# 4                     Mochila      36
# 5                Vaso térmico      38
# 6          Guitarra eléctrica      38
# 7           Asistente virtual      39
# 8   Auriculares con micrófono      39
# 9                  Cubertería      39
# 10                Muñeca bebé      39
# # Análisis De Tienda 4
# <style type="text/css">
# </style>
# <table id="T_2a1ad">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2a1ad_row0_col0" class="data row0 col0" >Ingresos Totales</td>
#       <td id="T_2a1ad_row0_col1" class="data row0 col1" >1038375700.000000</td>
#     </tr>
#     <tr>
#       <td id="T_2a1ad_row1_col0" class="data row1 col0" >Costo de envio promedio</td>
#       <td id="T_2a1ad_row1_col1" class="data row1 col1" >23459.457167</td>
#     </tr>
#     <tr>
#       <td id="T_2a1ad_row2_col0" class="data row2 col0" >Promedio de calificación</td>
#       <td id="T_2a1ad_row2_col1" class="data row2 col1" >4.00</td>
#     </tr>
#   </tbody>
# </table>
# ### Ventas por categoría
#                  Categoría  Ventas
# 1                  Muebles     480
# 2             Electrónicos     451
# 3                 Juguetes     338
# 4     Deportes y diversión     277
# 5        Electrodomésticos     254
# 6  Artículos para el hogar     201
# 7                   Libros     187
# 8   Instrumentos musicales     170
# ### Productos Más Vendidos
#                      Producto  Ventas
# 1                    Cama box      62
# 2                  Cubertería      59
# 3     Dashboards con Power BI      56
# 4                   Cama king      56
# 5   Carrito de control remoto      55
# 6             Mesa de comedor      55
# 7               Mesa de noche      55
# 8                    Smart TV      54
# 9     Bloques de construcción      54
# 10                  Pandereta      52
# ### Productos Menos Vendidos
#                        Producto  Ventas
# 1            Guitarra eléctrica      33
# 2                       Armario      34
# 3             Guitarra acústica      37
# 4   Ciencia de datos con Python      38
# 5              Lavadora de ropa      38
# 6                  Refrigerador      38
# 7             Ajedrez de madera      39
# 8                    Smartwatch      39
# 9                  Celular ABXY      39
# 10             Silla de oficina      40
# # Análisis De Tiendas
# ## Análisis De Ingresos por Tienda
# ## Análisis De Costos De Envio Promedio por Tienda
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e026e32593547c9320a36cf250b84717 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e026e32593547c9320a36cf250b84717&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e026e32593547c9320a36cf250b84717 = L.map(
#                 &quot;map_e026e32593547c9320a36cf250b84717&quot;,
#                 {
#                     center: [5.428909498675146, -74.76010839639639],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c2d02f126d79ac7afa493f1d351c54f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c2d02f126d79ac7afa493f1d351c54f.addTo(map_e026e32593547c9320a36cf250b84717);
#
#
#             var feature_group_8d621105b09b9899c45921a6ce15f3ca = L.featureGroup(
#                 {
# }
#             );
#
#
#             var heat_map_98005267a564149564eeb6102f704286 = L.heatLayer(
#                 [[4.60971, -74.08175], [6.25184, -75.56359], [10.39972, -75.51444], [3.43722, -76.5225], [6.25184, -75.56359], [3.43722, -76.5225], [4.60971, -74.08175], [11.24079, -74.19904], [4.60971, -74.08175], [4.60971, -74.08175], [4.60971, -74.08175], [10.39972, -75.51444], [6.25184, -75.56359], [4.81333, -75.69611], [4.60971, -74.08175], [3.43722, -76.5225], [6.25184, -75.56359], [11.24079, -74.19904], [4.60971, -74.08175], [6.25184, -75.56359], [3.43722, -76.5225], [4.60971, -74.08175], [6.25184, -75.56359], [4.60971, -74.08175], [6.25184, -75.56359], [4.60971, -74.08175], [6.25184, -75.56359], [4.60971, -74.08175], [10.96854, -74.78132], [4.60971, -74.08175], [6.25184, -75.56359], [6.25184, -75.56359], [6.25184, -75.56359], [4.60971, -74.08175], [4.60971, -74.08175], [6.25184, -75.56359], [4.60971, -74.08175], [3.43722, -76.5225], [4.60971, -74.08175], [4.142, -73.62664], [3.43722, -76.5225], [3.43722, -76.5225], [6.25184, -75.56359], [4.60971, -74.08175], [4.60971, -74.08175], [6.25184, -75.56359], [3.8653, -67.9239], [6.25184, -75.56359], [3.43722, -76.5225], [7.89391, -72.50782], [3.43722, -76.5225], [6.25184, -75.56359], [4.60971, -74.08175], [3.43722, -76.5225], [6.25184, -75.56359], [4.60971, -74.08175], [7.89391, -72.50782], [4.60971, -74.08175], [4.60971, -74.08175], [6.25184, -75.56359], [5.06889, -75.51738], [4.60971, -74.08175], [6.25184, -75.56359], [4.60971, -74.08175], [4.60971, -74.08175], [6.25184, -75.56359], [6.25184, -75.56359], [3.43722, -76.5225], [2.9273, -75.28189], [4.60971, -74.08175], [4.60971, -74.08175], [6.25184, -75.56359], [7.12539, -73.1198], [3.43722, -76.5225], [4.60971, -74.08175], [4.60971, -74.08175], [10.46314, -73.25322], [6.25184, -75.56359], [6.25184, -75.56359], [4.60971, -74.08175], [10.96854, -74.78132], [4.60971, -74.08175], [6.25184, -75.56359], [6.25184, -75.56359], [10.39972, -75.51444], [1.21361, -77.28111], [4.60971, -74.08175], [6.25184, -75.56359], [4.60971, -74.08175], [4.60971, -74.08175], [3.43722, -76.5225], [4.60971, -74.08175], [4.60971, -74.08175], [10.46314, -73.25322], [6.25184, -75.56359], [7.89391, -72.50782], [3.43722, -76.5225], [4.60971, -74.08175], [6.25184, -75.56359], [6.25184, -75.56359], [4.60971, -74.08175], [6.25184, -75.56359], [4.60971, -74.08175], [4.60971, -74.08175], [4.60971, -74.08175], [6.25184, -75.56359], [4.60971, -74.08175], [11.54444, -72.90722], [4.60971, -74.08175], [4.60971, -74.08175], [4.60971, -74.08175], [4.60971, -74.08175], [4.60971, -74.08175], [4.60971, -74.08175], [4.60971, -74.08175], [4.60971, -74.08175], [10.39972, -75.51444], [4.142, -73.62664], [1.21361, -77.28111], [4.60971, -74.08175], [3.43722, -76.5225], [4.60971, -74.08175], [6.25184, -75.56359], [6.25184, -75.56359], [4.60971, -74.08175], [4.60971, -74.08175], [1.21361, -77.28111], [7.12539, -73.1198], [3.43722, -76.5225], [6.25184, -75.56359], [6.25184, -75.56359], [4.60971, -74.08175], [6.25184, -75.56359], [10.39972, -75.51444], [4.60971, -74.08175], [7.12539, -73.1198], [6.25184, -75.56359], [6.25184, -75.56359], [4.60971, -74.08175], [4.60971, -74.08175], [4.81333, -75.69611], [4.60971, -74.08175], [3.43722, -76.5225], [4.81333, -75.69611], [6.25184, -75.56359], [3.43722, -76.5225], [7.12539, -73.1198], [4.81333, -75.69611], [4.53389, -75.68111], [6.25184, -75.56359], [4.81333, -75.69611], [4.60971, -74.08175], [3.43722, -76.5225], [6.25184, -75.56359], [3.43722, -76.5225], [3.43722, -76.5225], [3.43722, -76.5225], [4.60971, -74.08175], [4.60971, -74.08175], [10.96854, -74.78
